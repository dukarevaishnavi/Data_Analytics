# %% [markdown]
# # Tuple In Python - Created using ()
# # works similar to list but immuatble in nature unlike list
# # ordered collection of objects of different data types.

# %%
t1=(1,2,3,4,5)
print(t1)
# Out:
# (1, 2, 3, 4, 5)

# %%
t1[2]
# Out:
# 3

# %%
# we cannot update the item value
t1.append(7);
t.remove()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 # we cannot update the item value
# ----> 2 t1.append(7);
#       3 t.remove()
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
del t1

# %%
t1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 t1
#
# NameError: name 't1' is not defined

# %%
t1=("kdjndnf",2,3,[3,5,7])
t1
# Out:
# ('kdjndnf', 2, 3, [3, 5, 7])

# %%
t1=()
t1
type(t1)
# Out:
# tuple

# %%
#creating single element tuple

# %%
t4=(5,)
t4
# Out:
# (5,)

# %%
# Slicing indexing is similar to list.
# in tuple if we want to store highly sensible data then we can use tuple
# once declared memory allocated fixed.
# item access fast
# methods - len , min , max , sum

# %%
# in tuple there are only 2 methods count and index

# %%
t6=("vaishnavi","kebd","dwkjbcekd","ewkjnde","abc","abc")
# Out:
# 0

# %%
t6.count("vaishnavi")
# Out:
# 1

# %%
t6.index("abc")
# Out:
# 4

# %% [markdown]
# # Tuple Packing  -- when we assign more than one values with comma to a variable python packs those value
# # inside a single tuple

# %%
b="marathi","python","english"
b
# Out:
# ('marathi', 'python', 'english')

# %%
m,p,e=b
print(m)
print(p)
print(e)
# Out:
# marathi
# python
# english

# %%
v=b[0]
v
# Out:
# 'marathi'

# %%
v=b[1]
v
# Out:
# 'python'

# %%
t5=1,2,3,4,5,6,5,6,7,8
t5
# Out:
# (1, 2, 3, 4, 5, 6, 5, 6, 7, 8)

# %%
a,*b=t5
# Out:
# 1

# %%
a # it returns the list
# Out:
# [1, 2, 3, 4, 5, 6, 5, 6, 7]

# %%
*a,b=t5
b
# Out:
# 8

# %%
_,_,_,v,w,_,_,_,_,_=t5
v
# Out:
# 4

# %%
# '_' (underscore) for skipping the items

# %%
p=(100,200,300,400,500,600,700,800,900)
_,q,*m,s,_,_=p
q
# Out:
# 200

# %%
m
# Out:
# [300, 400, 500, 600]

# %%
s
# Out:
# 700

# %%
*a,b,_,_,_=p
b
# Out:
# 600

# %% [markdown]
# # variable swapping

# %%
word1="python"
word2="sql"
print(word1,word2)
word1,word2=word2,word1
print(word1)
print(word2)
# Out:
# python sql
# sql
# python

# %%
t = (10, 20, 30)
a,b,c=t
print(a)
print(b)
print(c)
# Out:
# 10
# 20
# 30
