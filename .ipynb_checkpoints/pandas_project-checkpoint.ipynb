# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
sales_data=pd.read_csv(r"C:\Users\HP\Downloads\sales_data (1).csv")
sales_data
# Out:
#    transaction_id customer_id      customer_name                    email  \
# 0          TRX001        C001         John Smith           john@email.com
# 1          TRX002        C002      Sarah Johnson   sarah.johnson@mail.com
# 2          TRX003        C003      MIKE WILLIAMS           mike@yahoo.com
# 3          TRX004        C001         John Smith     john.smith@email.com
# 4          TRX005        C004         emily chen        emily_c@email.com
# 5          TRX006        C005       Robert Brown         robert@email.com
# 6          TRX007        C002      Sarah Johnson          sarah@email.com
# 7          TRX008        C006   Jessica Martinez     j.martinez@email.com
# 8          TRX009        C007          David Lee    david.lee@hotmail.com
# 9          TRX010        C003      Mike Williams  mike.williams@email.com
# 10         TRX011        C008        Anna Garcia    anna_garcia@email.com
# 11         TRX012        C009  Christopher White          chris@email.com
# 12         TRX013        C010     Laura Martinez          laura@email.com
# 13         TRX014        C002      Sarah Johnson        sarah.j@email.com
# 14         TRX015        C011    Michael Johnson      michael.j@email.com
# 15         TRX016        C012     Patricia Brown       patricia@email.com
# 16         TRX017        C013       ANDREW DAVIS   andrew.davis@yahoo.com
# 17         TRX018        C014      Nicole Wilson       nicole_w@email.com
# 18         TRX019        C015   Daniel Rodriguez         daniel@email.com
# 19         TRX020        C016         Sandra Lee     sandra.lee@email.com
# 20         TRX021        C002      SARAH JOHNSON        sarah_j@email.com
# 21         TRX022        C017       Thomas Clark         thomas@email.com
# 22         TRX023        C018      Amanda Taylor       amanda.t@email.com
# 23         TRX024        C019       Kevin Miller        kevin_m@email.com
# 24         TRX025        C020    Sophia Anderson         sophia@email.com
# 25         TRX026        C021     Matthew Thomas      matthew.t@email.com
# 26         TRX027        C022     Olivia Jackson       olivia.j@email.com
# 27         TRX028        C023  Christopher White    christopher@email.com
# 28         TRX029        C024    Isabella Harris     isabella.h@email.com
# 29         TRX030        C025    Benjamin Martin       b.martin@email.com
#
#    purchase_date product_category             product_name  quantity  \
# 0      1/15/2024      Electronics                   Laptop         1
# 1      1/16/2024            Books             Python Guide         3
# 2      1/16/2024      Electronics                USB Cable        10
# 3      1/17/2024         Clothing                  T-Shirt         2
# 4      1/18/2024            Books         Data Science 101         1
# 5      1/19/2024      Electronics                  Monitor         1
# 6      1/20/2024         Clothing                    Jeans         1
# 7      1/21/2024             Home             Coffee Maker         1
# 8      1/22/2024      Electronics               Headphones         2
# 9      1/23/2024            Books          The Art of Code         1
# 10     1/24/2024         Clothing                    Dress         3
# 11     1/25/2024      Electronics                 Keyboard         1
# 12     1/26/2024             Home                  Blender         1
# 13     1/27/2024            Books  Machine Learning Basics         2
# 14     1/28/2024      Electronics                  Monitor         1
# 15     1/29/2024         Clothing                   Jacket         2
# 16     1/30/2024            Books            Web Dev Guide         1
# 17     1/31/2024             Home                  Toaster         2
# 18      2/1/2024      Electronics                    Mouse         5
# 19      2/2/2024         Clothing                  Sweater         1
# 20      2/3/2024            Books          Database Design         1
# 21      2/4/2024      Electronics                  USB Hub         3
# 22      2/5/2024             Home                Microwave         1
# 23      2/6/2024         Clothing                    Shoes         1
# 24      2/7/2024            Books          AI Fundamentals         1
# 25      2/8/2024      Electronics                  Monitor         1
# 26      2/9/2024         Clothing                    Pants         2
# 27     2/10/2024             Home                Air Fryer         1
# 28     2/11/2024            Books          Python Advanced         1
# 29     2/12/2024      Electronics                   Laptop         1
#
#     unit_price  total_amount payment_method shipping_country  customer_age  \
# 0       999.99        999.99    Credit Card              USA            28
# 1        29.99         89.97         PayPal           Canada            35
# 2         5.99           NaN     Debit Card              USA            40
# 3        19.99         39.98    Credit Card              USA            28
# 4        45.00         45.00    Credit Card               UK            42
# 5       349.99           NaN         PayPal              USA            51
# 6        79.99         79.99    Credit Card           Canada            35
# 7        89.99         89.99     Debit Card              USA            29
# 8       149.99        299.98    Credit Card              USA            33
# 9        55.00         55.00         PayPal              USA            34
# 10       59.99        179.97    Credit Card           France            26
# 11       99.99         99.99    Credit Card          Germany            45
# 12      129.99        129.99         PayPal              USA            38
# 13       65.00        130.00     Debit Card           Canada            35
# 14      349.99        349.99    Credit Card              USA            41
# 15      299.99        299.99    Credit Card              USA            55
# 16       39.99         39.99         PayPal              USA            29
# 17       34.99         69.98    Credit Card              USA            31
# 18       29.99         69.80    Credit Card              USA            27
# 19       89.99         89.99    Credit Card              USA            33
# 20       55.00         55.00         PayPal           Canada            35
# 21       24.99         74.97     Debit Card              USA            50
# 22      199.99        199.99    Credit Card              USA            42
# 23      129.99        129.99         PayPal              USA            38
# 24       49.99         49.99    Credit Card              USA            28
# 25      349.99        349.99    Credit Card              USA            35
# 26       69.99        139.98     Debit Card           Canada            31
# 27      159.99        159.99    Credit Card              USA            44
# 28       59.99         59.99         PayPal              USA            26
# 29     1299.99      -1299.99    Credit Card              USA            52
#
#     discount_percent  Unnamed: 14
# 0                  0          NaN
# 1                 10          NaN
# 2                  5          NaN
# 3                  0          NaN
# 4                 15          NaN
# 5                 10          NaN
# 6                 20          NaN
# 7                  0          NaN
# 8                  0          NaN
# 9                  0          NaN
# 10                12          NaN
# 11                 5          NaN
# 12                25          NaN
# 13                 0          NaN
# 14                 0          NaN
# 15                15          NaN
# 16                10          NaN
# 17                 0          NaN
# 18                 5          5.0
# 19                 0          NaN
# 20                20          NaN
# 21                 0          NaN
# 22                10          NaN
# 23                25          NaN
# 24                 0          NaN
# 25                 5          NaN
# 26                15          NaN
# 27                 0          NaN
# 28                 0          NaN
# 29                40          NaN

# %%
sales_data.shape
# Out:
# (30, 15)

# %%
Display basic info:
   - Shape (rows, columns)
   - Data types
   - First and last few rows
   - Summary statistics
   - Missing value counts
# Out:
#   Cell In[44], line 1
#     Display basic info:
#             ^
# SyntaxError: invalid syntax

# %%
# Data types
sales_data.dtypes
# Out:
# transaction_id       object
# customer_id          object
# customer_name        object
# email                object
# purchase_date        object
# product_category     object
# product_name         object
# quantity              int64
# unit_price          float64
# total_amount        float64
# payment_method       object
# shipping_country     object
# customer_age          int64
# discount_percent      int64
# Unnamed: 14         float64
# dtype: object

# %%
# First and last few rows
sales_data.head()
# Out:
#   transaction_id customer_id  customer_name                   email  \
# 0         TRX001        C001     John Smith          john@email.com
# 1         TRX002        C002  Sarah Johnson  sarah.johnson@mail.com
# 2         TRX003        C003  MIKE WILLIAMS          mike@yahoo.com
# 3         TRX004        C001     John Smith    john.smith@email.com
# 4         TRX005        C004     emily chen       emily_c@email.com
#
#   purchase_date product_category      product_name  quantity  unit_price  \
# 0     1/15/2024      Electronics            Laptop         1      999.99
# 1     1/16/2024            Books      Python Guide         3       29.99
# 2     1/16/2024      Electronics         USB Cable        10        5.99
# 3     1/17/2024         Clothing           T-Shirt         2       19.99
# 4     1/18/2024            Books  Data Science 101         1       45.00
#
#    total_amount payment_method shipping_country  customer_age  \
# 0        999.99    Credit Card              USA            28
# 1         89.97         PayPal           Canada            35
# 2           NaN     Debit Card              USA            40
# 3         39.98    Credit Card              USA            28
# 4         45.00    Credit Card               UK            42
#
#    discount_percent  Unnamed: 14
# 0                 0          NaN
# 1                10          NaN
# 2                 5          NaN
# 3                 0          NaN
# 4                15          NaN

# %%
sales_data.tail()
# Out:
#    transaction_id customer_id      customer_name                  email  \
# 25         TRX026        C021     Matthew Thomas    matthew.t@email.com
# 26         TRX027        C022     Olivia Jackson     olivia.j@email.com
# 27         TRX028        C023  Christopher White  christopher@email.com
# 28         TRX029        C024    Isabella Harris   isabella.h@email.com
# 29         TRX030        C025    Benjamin Martin     b.martin@email.com
#
#    purchase_date product_category     product_name  quantity  unit_price  \
# 25      2/8/2024      Electronics          Monitor         1      349.99
# 26      2/9/2024         Clothing            Pants         2       69.99
# 27     2/10/2024             Home        Air Fryer         1      159.99
# 28     2/11/2024            Books  Python Advanced         1       59.99
# 29     2/12/2024      Electronics           Laptop         1     1299.99
#
#     total_amount payment_method shipping_country  customer_age  \
# 25        349.99    Credit Card              USA            35
# 26        139.98     Debit Card           Canada            31
# 27        159.99    Credit Card              USA            44
# 28         59.99         PayPal              USA            26
# 29      -1299.99    Credit Card              USA            52
#
#     discount_percent  Unnamed: 14
# 25                 5          NaN
# 26                15          NaN
# 27                 0          NaN
# 28                 0          NaN
# 29                40          NaN

# %%
# Summary statistics
sales_data.describe()
# Out:
#         quantity   unit_price  total_amount  customer_age  discount_percent  \
# count  30.000000    30.000000     28.000000     30.000000         30.000000
# mean    1.833333   180.858000    109.981786     36.533333          8.233333
# std     1.801978   284.858912    334.329231      8.186336         10.060792
# min     1.000000     5.990000  -1299.990000     26.000000          0.000000
# 25%     1.000000    46.247500     58.742500     29.500000          0.000000
# 50%     1.000000    74.990000     89.990000     35.000000          5.000000
# 75%     2.000000   157.490000    164.985000     41.750000         14.250000
# max    10.000000  1299.990000    999.990000     55.000000         40.000000
#
#        Unnamed: 14
# count          1.0
# mean           5.0
# std            NaN
# min            5.0
# 25%            5.0
# 50%            5.0
# 75%            5.0
# max            5.0

# %%
#  - Missing value counts
sales_data.isnull().sum()
# Out:
# transaction_id       0
# customer_id          0
# customer_name        0
# email                0
# purchase_date        0
# product_category     0
# product_name         0
# quantity             0
# unit_price           0
# total_amount         2
# payment_method       0
# shipping_country     0
# customer_age         0
# discount_percent     0
# Unnamed: 14         29
# dtype: int64

# %%
# 3. Identify all data quality issues in the dataset

# %%
**Handle Missing Values:**
   - Fill missing `quantity` values with 1 (default order quantity)
   - Fill missing `total_amount` by calculating: `quantity × unit_price`
   - Fill missing `customer_age` with the median age
   - Drop rows where critical information is completely missing
# Out:
#   Cell In[51], line 3
#     - Fill missing `total_amount` by calculating: `quantity × unit_price`
#                                                             ^
# SyntaxError: invalid character '×' (U+00D7)

# %%
sales_data["quantity"].fillna(1)
# Out:
# 0      1
# 1      3
# 2     10
# 3      2
# 4      1
# 5      1
# 6      1
# 7      1
# 8      2
# 9      1
# 10     3
# 11     1
# 12     1
# 13     2
# 14     1
# 15     2
# 16     1
# 17     2
# 18     5
# 19     1
# 20     1
# 21     3
# 22     1
# 23     1
# 24     1
# 25     1
# 26     2
# 27     1
# 28     1
# 29     1
# Name: quantity, dtype: int64

# %%
# Fill missing `total_amount` by calculating: `quantity × unit_price`
sales_data["total_amount"].fillna(sales_data["quantity"]*sales_data["unit_price"])
# Out:
# 0      999.99
# 1       89.97
# 2       59.90
# 3       39.98
# 4       45.00
# 5      349.99
# 6       79.99
# 7       89.99
# 8      299.98
# 9       55.00
# 10     179.97
# 11      99.99
# 12     129.99
# 13     130.00
# 14     349.99
# 15     299.99
# 16      39.99
# 17      69.98
# 18      69.80
# 19      89.99
# 20      55.00
# 21      74.97
# 22     199.99
# 23     129.99
# 24      49.99
# 25     349.99
# 26     139.98
# 27     159.99
# 28      59.99
# 29   -1299.99
# Name: total_amount, dtype: float64

# %%
# Fill missing `customer_age` with the median age
sales_data["customer_age"].fillna(sales_data["customer_age"].median())
# Out:
# 0     28
# 1     35
# 2     40
# 3     28
# 4     42
# 5     51
# 6     35
# 7     29
# 8     33
# 9     34
# 10    26
# 11    45
# 12    38
# 13    35
# 14    41
# 15    55
# 16    29
# 17    31
# 18    27
# 19    33
# 20    35
# 21    50
# 22    42
# 23    38
# 24    28
# 25    35
# 26    31
# 27    44
# 28    26
# 29    52
# Name: customer_age, dtype: int64

# %%
#  Drop rows where critical information is completely missing
sales_data.dropna()
# Out:
#    transaction_id customer_id     customer_name             email  \
# 18         TRX019        C015  Daniel Rodriguez  daniel@email.com
#
#    purchase_date product_category product_name  quantity  unit_price  \
# 18      2/1/2024      Electronics        Mouse         5       29.99
#
#     total_amount payment_method shipping_country  customer_age  \
# 18          69.8    Credit Card              USA            27
#
#     discount_percent  Unnamed: 14
# 18                 5          5.0

# %%
*Standardize Text Data:**
   - Convert all customer names to Title Case (consistent formatting)
   - Convert emails to lowercase
   - Trim whitespace from all string columns

6. **Fix Data Types:**
   - Ensure all numeric columns (quantity, unit_price, total_amount, discount_percent, customer_age) are numeric
   - Convert purchase_date to datetime format
   - Verify payment_method and product_category are strings

7. **Remove/Fix Duplicates:**
   - Identify duplicate transactions (same transaction_id)
   - Identify duplicate customers with slightly different names/emails
   - Keep only one record per duplicate (based on most recent date)

8. **Fix Invalid Data:**
   - Remove or fix rows with negative total_amount
   - Ensure discount_percent is between 0 and 100
   - Verify quantity is positive
   - Fix records where unit_price doesn't match total_amount / quantity
# Out:
#   Cell In[56], line 20
#     - Fix records where unit_price doesn't match total_amount / quantity
#                                         ^
# SyntaxError: unterminated string literal (detected at line 20)

# %%
*Create New Columns:**
   - `net_amount`: total_amount after applying discount
   - `year_month`: Extract year-month from purchase_date
   - `customer_segment`: Categorize customers as:
     - "High Value" if total spending > $500
     - "Medium Value" if total spending $100-$500
     - "Low Value" if total spending < $100
# Out:
#   Cell In[57], line 1
#     *Create New Columns:**
#             ^
# SyntaxError: invalid syntax

# %%
# - `net_amount`: total_amount after applying discount
sales_data["net_amount"]=sales_data["total_amount"]*(20/100)
sales_data
# Out:
#    transaction_id customer_id      customer_name                    email  \
# 0          TRX001        C001         John Smith           john@email.com
# 1          TRX002        C002      Sarah Johnson   sarah.johnson@mail.com
# 2          TRX003        C003      MIKE WILLIAMS           mike@yahoo.com
# 3          TRX004        C001         John Smith     john.smith@email.com
# 4          TRX005        C004         emily chen        emily_c@email.com
# 5          TRX006        C005       Robert Brown         robert@email.com
# 6          TRX007        C002      Sarah Johnson          sarah@email.com
# 7          TRX008        C006   Jessica Martinez     j.martinez@email.com
# 8          TRX009        C007          David Lee    david.lee@hotmail.com
# 9          TRX010        C003      Mike Williams  mike.williams@email.com
# 10         TRX011        C008        Anna Garcia    anna_garcia@email.com
# 11         TRX012        C009  Christopher White          chris@email.com
# 12         TRX013        C010     Laura Martinez          laura@email.com
# 13         TRX014        C002      Sarah Johnson        sarah.j@email.com
# 14         TRX015        C011    Michael Johnson      michael.j@email.com
# 15         TRX016        C012     Patricia Brown       patricia@email.com
# 16         TRX017        C013       ANDREW DAVIS   andrew.davis@yahoo.com
# 17         TRX018        C014      Nicole Wilson       nicole_w@email.com
# 18         TRX019        C015   Daniel Rodriguez         daniel@email.com
# 19         TRX020        C016         Sandra Lee     sandra.lee@email.com
# 20         TRX021        C002      SARAH JOHNSON        sarah_j@email.com
# 21         TRX022        C017       Thomas Clark         thomas@email.com
# 22         TRX023        C018      Amanda Taylor       amanda.t@email.com
# 23         TRX024        C019       Kevin Miller        kevin_m@email.com
# 24         TRX025        C020    Sophia Anderson         sophia@email.com
# 25         TRX026        C021     Matthew Thomas      matthew.t@email.com
# 26         TRX027        C022     Olivia Jackson       olivia.j@email.com
# 27         TRX028        C023  Christopher White    christopher@email.com
# 28         TRX029        C024    Isabella Harris     isabella.h@email.com
# 29         TRX030        C025    Benjamin Martin       b.martin@email.com
#
#    purchase_date product_category             product_name  quantity  \
# 0      1/15/2024      Electronics                   Laptop         1
# 1      1/16/2024            Books             Python Guide         3
# 2      1/16/2024      Electronics                USB Cable        10
# 3      1/17/2024         Clothing                  T-Shirt         2
# 4      1/18/2024            Books         Data Science 101         1
# 5      1/19/2024      Electronics                  Monitor         1
# 6      1/20/2024         Clothing                    Jeans         1
# 7      1/21/2024             Home             Coffee Maker         1
# 8      1/22/2024      Electronics               Headphones         2
# 9      1/23/2024            Books          The Art of Code         1
# 10     1/24/2024         Clothing                    Dress         3
# 11     1/25/2024      Electronics                 Keyboard         1
# 12     1/26/2024             Home                  Blender         1
# 13     1/27/2024            Books  Machine Learning Basics         2
# 14     1/28/2024      Electronics                  Monitor         1
# 15     1/29/2024         Clothing                   Jacket         2
# 16     1/30/2024            Books            Web Dev Guide         1
# 17     1/31/2024             Home                  Toaster         2
# 18      2/1/2024      Electronics                    Mouse         5
# 19      2/2/2024         Clothing                  Sweater         1
# 20      2/3/2024            Books          Database Design         1
# 21      2/4/2024      Electronics                  USB Hub         3
# 22      2/5/2024             Home                Microwave         1
# 23      2/6/2024         Clothing                    Shoes         1
# 24      2/7/2024            Books          AI Fundamentals         1
# 25      2/8/2024      Electronics                  Monitor         1
# 26      2/9/2024         Clothing                    Pants         2
# 27     2/10/2024             Home                Air Fryer         1
# 28     2/11/2024            Books          Python Advanced         1
# 29     2/12/2024      Electronics                   Laptop         1
#
#     unit_price  total_amount payment_method shipping_country  customer_age  \
# 0       999.99        999.99    Credit Card              USA            28
# 1        29.99         89.97         PayPal           Canada            35
# 2         5.99           NaN     Debit Card              USA            40
# 3        19.99         39.98    Credit Card              USA            28
# 4        45.00         45.00    Credit Card               UK            42
# 5       349.99           NaN         PayPal              USA            51
# 6        79.99         79.99    Credit Card           Canada            35
# 7        89.99         89.99     Debit Card              USA            29
# 8       149.99        299.98    Credit Card              USA            33
# 9        55.00         55.00         PayPal              USA            34
# 10       59.99        179.97    Credit Card           France            26
# 11       99.99         99.99    Credit Card          Germany            45
# 12      129.99        129.99         PayPal              USA            38
# 13       65.00        130.00     Debit Card           Canada            35
# 14      349.99        349.99    Credit Card              USA            41
# 15      299.99        299.99    Credit Card              USA            55
# 16       39.99         39.99         PayPal              USA            29
# 17       34.99         69.98    Credit Card              USA            31
# 18       29.99         69.80    Credit Card              USA            27
# 19       89.99         89.99    Credit Card              USA            33
# 20       55.00         55.00         PayPal           Canada            35
# 21       24.99         74.97     Debit Card              USA            50
# 22      199.99        199.99    Credit Card              USA            42
# 23      129.99        129.99         PayPal              USA            38
# 24       49.99         49.99    Credit Card              USA            28
# 25      349.99        349.99    Credit Card              USA            35
# 26       69.99        139.98     Debit Card           Canada            31
# 27      159.99        159.99    Credit Card              USA            44
# 28       59.99         59.99         PayPal              USA            26
# 29     1299.99      -1299.99    Credit Card              USA            52
#
#     discount_percent  Unnamed: 14  net_amount
# 0                  0          NaN     199.998
# 1                 10          NaN      17.994
# 2                  5          NaN         NaN
# 3                  0          NaN       7.996
# 4                 15          NaN       9.000
# 5                 10          NaN         NaN
# 6                 20          NaN      15.998
# 7                  0          NaN      17.998
# 8                  0          NaN      59.996
# 9                  0          NaN      11.000
# 10                12          NaN      35.994
# 11                 5          NaN      19.998
# 12                25          NaN      25.998
# 13                 0          NaN      26.000
# 14                 0          NaN      69.998
# 15                15          NaN      59.998
# 16                10          NaN       7.998
# 17                 0          NaN      13.996
# 18                 5          5.0      13.960
# 19                 0          NaN      17.998
# 20                20          NaN      11.000
# 21                 0          NaN      14.994
# 22                10          NaN      39.998
# 23                25          NaN      25.998
# 24                 0          NaN       9.998
# 25                 5          NaN      69.998
# 26                15          NaN      27.996
# 27                 0          NaN      31.998
# 28                 0          NaN      11.998
# 29                40          NaN    -259.998

# %%
sales_data["year_month"] = sales_data["purchase_date"].dt.strftime("%Y-%m")
sales_data
# Out:
#    transaction_id customer_id      customer_name                    email  \
# 0          TRX001        C001         John Smith           john@email.com
# 1          TRX002        C002      Sarah Johnson   sarah.johnson@mail.com
# 2          TRX003        C003      MIKE WILLIAMS           mike@yahoo.com
# 3          TRX004        C001         John Smith     john.smith@email.com
# 4          TRX005        C004         emily chen        emily_c@email.com
# 5          TRX006        C005       Robert Brown         robert@email.com
# 6          TRX007        C002      Sarah Johnson          sarah@email.com
# 7          TRX008        C006   Jessica Martinez     j.martinez@email.com
# 8          TRX009        C007          David Lee    david.lee@hotmail.com
# 9          TRX010        C003      Mike Williams  mike.williams@email.com
# 10         TRX011        C008        Anna Garcia    anna_garcia@email.com
# 11         TRX012        C009  Christopher White          chris@email.com
# 12         TRX013        C010     Laura Martinez          laura@email.com
# 13         TRX014        C002      Sarah Johnson        sarah.j@email.com
# 14         TRX015        C011    Michael Johnson      michael.j@email.com
# 15         TRX016        C012     Patricia Brown       patricia@email.com
# 16         TRX017        C013       ANDREW DAVIS   andrew.davis@yahoo.com
# 17         TRX018        C014      Nicole Wilson       nicole_w@email.com
# 18         TRX019        C015   Daniel Rodriguez         daniel@email.com
# 19         TRX020        C016         Sandra Lee     sandra.lee@email.com
# 20         TRX021        C002      SARAH JOHNSON        sarah_j@email.com
# 21         TRX022        C017       Thomas Clark         thomas@email.com
# 22         TRX023        C018      Amanda Taylor       amanda.t@email.com
# 23         TRX024        C019       Kevin Miller        kevin_m@email.com
# 24         TRX025        C020    Sophia Anderson         sophia@email.com
# 25         TRX026        C021     Matthew Thomas      matthew.t@email.com
# 26         TRX027        C022     Olivia Jackson       olivia.j@email.com
# 27         TRX028        C023  Christopher White    christopher@email.com
# 28         TRX029        C024    Isabella Harris     isabella.h@email.com
# 29         TRX030        C025    Benjamin Martin       b.martin@email.com
#
#    purchase_date product_category             product_name  quantity  \
# 0     2024-01-15      Electronics                   Laptop         1
# 1     2024-01-16            Books             Python Guide         3
# 2     2024-01-16      Electronics                USB Cable        10
# 3     2024-01-17         Clothing                  T-Shirt         2
# 4     2024-01-18            Books         Data Science 101         1
# 5     2024-01-19      Electronics                  Monitor         1
# 6     2024-01-20         Clothing                    Jeans         1
# 7     2024-01-21             Home             Coffee Maker         1
# 8     2024-01-22      Electronics               Headphones         2
# 9     2024-01-23            Books          The Art of Code         1
# 10    2024-01-24         Clothing                    Dress         3
# 11    2024-01-25      Electronics                 Keyboard         1
# 12    2024-01-26             Home                  Blender         1
# 13    2024-01-27            Books  Machine Learning Basics         2
# 14    2024-01-28      Electronics                  Monitor         1
# 15    2024-01-29         Clothing                   Jacket         2
# 16    2024-01-30            Books            Web Dev Guide         1
# 17    2024-01-31             Home                  Toaster         2
# 18    2024-02-01      Electronics                    Mouse         5
# 19    2024-02-02         Clothing                  Sweater         1
# 20    2024-02-03            Books          Database Design         1
# 21    2024-02-04      Electronics                  USB Hub         3
# 22    2024-02-05             Home                Microwave         1
# 23    2024-02-06         Clothing                    Shoes         1
# 24    2024-02-07            Books          AI Fundamentals         1
# 25    2024-02-08      Electronics                  Monitor         1
# 26    2024-02-09         Clothing                    Pants         2
# 27    2024-02-10             Home                Air Fryer         1
# 28    2024-02-11            Books          Python Advanced         1
# 29    2024-02-12      Electronics                   Laptop         1
#
#     unit_price  total_amount payment_method shipping_country  customer_age  \
# 0       999.99        999.99    Credit Card              USA            28
# 1        29.99         89.97         PayPal           Canada            35
# 2         5.99           NaN     Debit Card              USA            40
# 3        19.99         39.98    Credit Card              USA            28
# 4        45.00         45.00    Credit Card               UK            42
# 5       349.99           NaN         PayPal              USA            51
# 6        79.99         79.99    Credit Card           Canada            35
# 7        89.99         89.99     Debit Card              USA            29
# 8       149.99        299.98    Credit Card              USA            33
# 9        55.00         55.00         PayPal              USA            34
# 10       59.99        179.97    Credit Card           France            26
# 11       99.99         99.99    Credit Card          Germany            45
# 12      129.99        129.99         PayPal              USA            38
# 13       65.00        130.00     Debit Card           Canada            35
# 14      349.99        349.99    Credit Card              USA            41
# 15      299.99        299.99    Credit Card              USA            55
# 16       39.99         39.99         PayPal              USA            29
# 17       34.99         69.98    Credit Card              USA            31
# 18       29.99         69.80    Credit Card              USA            27
# 19       89.99         89.99    Credit Card              USA            33
# 20       55.00         55.00         PayPal           Canada            35
# 21       24.99         74.97     Debit Card              USA            50
# 22      199.99        199.99    Credit Card              USA            42
# 23      129.99        129.99         PayPal              USA            38
# 24       49.99         49.99    Credit Card              USA            28
# 25      349.99        349.99    Credit Card              USA            35
# 26       69.99        139.98     Debit Card           Canada            31
# 27      159.99        159.99    Credit Card              USA            44
# 28       59.99         59.99         PayPal              USA            26
# 29     1299.99      -1299.99    Credit Card              USA            52
#
#     discount_percent  Unnamed: 14  net_amount year_month
# 0                  0          NaN     199.998    2024-01
# 1                 10          NaN      17.994    2024-01
# 2                  5          NaN         NaN    2024-01
# 3                  0          NaN       7.996    2024-01
# 4                 15          NaN       9.000    2024-01
# 5                 10          NaN         NaN    2024-01
# 6                 20          NaN      15.998    2024-01
# 7                  0          NaN      17.998    2024-01
# 8                  0          NaN      59.996    2024-01
# 9                  0          NaN      11.000    2024-01
# 10                12          NaN      35.994    2024-01
# 11                 5          NaN      19.998    2024-01
# 12                25          NaN      25.998    2024-01
# 13                 0          NaN      26.000    2024-01
# 14                 0          NaN      69.998    2024-01
# 15                15          NaN      59.998    2024-01
# 16                10          NaN       7.998    2024-01
# 17                 0          NaN      13.996    2024-01
# 18                 5          5.0      13.960    2024-02
# 19                 0          NaN      17.998    2024-02
# 20                20          NaN      11.000    2024-02
# 21                 0          NaN      14.994    2024-02
# 22                10          NaN      39.998    2024-02
# 23                25          NaN      25.998    2024-02
# 24                 0          NaN       9.998    2024-02
# 25                 5          NaN      69.998    2024-02
# 26                15          NaN      27.996    2024-02
# 27                 0          NaN      31.998    2024-02
# 28                 0          NaN      11.998    2024-02
# 29                40          NaN    -259.998    2024-02

# %%
# `customer_segment`: Categorize customers as:
     # - "High Value" if total spending > $500
# "Medium Value" if total spending $100-$500
#  - "Low Value" if total spending < $100
sales_data["customer_segment"]=sales_data["total_amount"].apply(lambda x:"high" if sales_data["total_amount"]>500 elif sales_data["total_amount"].between(100,500) else "low value" sales_data["total_amount"])
sales_data
# Out:
#   Cell In[81], line 5
#     sales_data["customer_segment"]=sales_data["total_amount"].apply(lambda x:"high" if sales_data["total_amount"]>500 elif sales_data["total_amount"].between(100,500) else "low value" sales_data["total_amount"])
#                                                                              ^
# SyntaxError: expected 'else' after 'if' expression
