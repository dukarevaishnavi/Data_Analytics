# %%
# 1 1. What are Python data types? Name at least five built-in data types.

# Ans : Data Type is nothing but is tells whether what kind of value a variable can hold 
# Example: int , float,string,none,boolean

# %%
# 2 2. Explain the difference between mutable and immutable data types with examples.

# Ans : Mutable : It means the we can change the value after the craetion 
# e.g : list , dictionary , set

# Immutable : It means we cannot change the value once we declared
# e.g : int , float , string

# %%
# 4 4. What is indexing in Python? Give one example.

# Ans : Accessing elements of a sequence by using position
a="vaishnavi"
print(a[1])
# Out:
# a

# %%
# 5 5. What is slicing? Explain with a short example.

# Ans : Slicing means extracting a part from a given sequence.

a="vaishnavi"
# extract the first 4 charcaters 
print(a[0:5])
# Out:
# vaish

# %%
# 6 6. What is a set in Python? Mention two important properties of sets.

 # Ans : set are collection of multiple values which are stored inside a {}, but it does not allow duplicate values .
# sets are mutable,unordered

# %%
# 7 7. What is a dictionary? How are keys and values stored?

# Ans : It is collection of multiple values which stores the data in {} .
# in dictionary values are stored in the key value pair.
d1={"name":"vaishnavi"}
d1
# Out:
# {'name': 'vaishnavi'}

# %%
# 8 8. What does the type() function do? Give one example.

# And : it returns the what type of data a variable can stored
a="vaishnavi"
print(type(a))
# Out:
# <class 'str'>

# %%
# 9 9. What is the difference between append() and extend() methods in lists?

# Ans : append() :It can add only single value in a sequence.
# extend() : It can add multiple values in a sequenec.

# %%
# 10 10. What is the difference between remove() and pop() methods in lists?

# Ans : remove() : it cannot return a value . we have to provide a value .
# pop() : it return a removed element . if we cannot provide a index it remove the last element .

# %%
# 1 11. Create a string 'PythonProgramming' and print 'Programming' using slicing.

s1='PythonProgramming'
print(s1[6:])
# Out:
# Programming

# %%
# 2 12. Write a program to print the first and last character of a string using indexing.
s1='PythonProgramming'

print("First character:", s1[0])
print("Last character:", s1[-1])
# Out:
# First character: P
# Last character: g

# %%
# 3 13. Create a string 'DataScience' and print the first five characters using slicing.

s2="DataScience"
print(s2[0:5])
# Out:
# DataS

# %%
# 4 14. Write a program to repeat the string 'Hi' 5 times.
print("hi\n"*5)
# Out:
# hi
# hi
# hi
# hi
# hi

# %%
# 5 15. Create a list [10, 20, 30] and add 40 using append().

l1=[10, 20, 30]
l1.append(40)
l1
# Out:
# [10, 20, 30, 40]

# %%
# 6 16. Create a list [1,2,3] and add [4,5] using extend().

l2= [1,2,3] 
l2.extend([4,5])
l2
# Out:
# [1, 2, 3, 4, 5]

# %%
# 7 17. Create a list [5,10,15,20] and remove the value 10 using remove().

l3=[5,10,15,20]
l3.remove(10)
l3
# Out:
# [5, 15, 20]

# %%
# 8 18. Create a list [100,200,300] and remove the last element using pop().

l3=[100,200,300]
result=l3.pop()
print(result)
# Out:
# 300

# %%
# 9 19. Create a list [7,8,9] and insert 6 at index 0.

l4=[7,8,9]
l4.insert(0,6)
l4
# Out:
# [6, 7, 8, 9]

# %%
# 10 20. Create a list [10,20,30,40] and print the element at index 2.

l5=[10,20,30,40]
print(l5[2])
# Out:
# 30

# %%
# 11 21. Create a tuple (10,20,30,40) and print the second element.

t1=(10,20,30,40)
print(t1[2])
# Out:
# 30

# %%
# 12 22. Create a tuple (5,10,15,20,25) and print its length.

t2= (5,10,15,20,25)
print(len(t2))
# Out:
# 5

# %%
# 13 23. Convert the list [1,2,3,4] into a tuple.

l1= [1,2,3,4]
print(tuple(l1))
# Out:
# (1, 2, 3, 4)

# %%
# 14 24. Create a set {1,2,3} and add element 4 using add().

s1={1,2,3}
s1.add(4)
s1
# Out:
# {1, 2, 3, 4}

# %%
# 15 25. Create a set {10,20,30} and remove element 20.

s2={10,20,30} 
s2.remove(20)
s2
# Out:
# {10, 30}

# %%
# 16 26. Create two sets {1,2,3} and {3,4,5} and find their union.
s1={1,2,3} 
s2={3,4,5}
print(s1.union(s2))
# Out:
# {1, 2, 3, 4, 5}

# %%
# 17 27. Create two sets {1,2,3} and {2,3,4} and find their intersection.

s1={1,2,3}
s2={2,3,4}
print(s1.intersection(s2))
# Out:
# {2, 3}

# %%
# 18 28. Create dictionary {'name':'Rahul','age':21} and add 'city':'Pune'.

d1={'name':'Rahul','age':21}
d1["city"]="pune"
print(d1)
# Out:
# {'name': 'Rahul', 'age': 21, 'city': 'pune'}

# %%
# 19 29. Create dictionary {'a':10,'b':20,'c':30} and print all keys.

d1={'a':10,'b':20,'c':30}
d1.keys()
d1
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
# 20 30. Create dictionary {'x':100,'y':200} and print all values.

d2={'x':100,'y':200}
d2.items()
d2
# Out:
# {'x': 100, 'y': 200}
