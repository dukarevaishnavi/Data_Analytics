# %% [markdown]
# # Strings In Python
# . String character individually called as
# . every item has its own unique position
# . strings are ordered collection of characters
# . string can take from A-Z,a-z,0-9 and special characters and space as well

# %% [markdown]
# # creating a string with single quote

# %%
s1='python'
print(s1)
# Out:
# python

# %% [markdown]
# #  creating a string with double quote

# %%
s1="fjdbfd"
print(s1)
# Out:
# fjdbfd

# %% [markdown]
# # Slicing - It has start index and stop index
# . Start index  - from which item, should make a slice .
# . Stop index - till which item we should stop a slice and that item is exclusive .

# %%
s1="i like python"
print(s1[:6]);
# Out:
# i like

# %%
# Slicing also has Stepping 
# [Start index : stop index : step]
# step simply means after how much steps we are taking to select assign

# %%
s1="i like jdbsbcjdcb"
print(s1[0:6:2])
# Out:
# ilk

# %%
s1="retupmoc"
print(s1[7:-5:-1])
# Out:
# comp

# %% [markdown]
# # Negative Slicing

# %%
# String Immutability

# %%
# String built in Methods

# %%
s2 = "vaishnavi"
s2.title();
