# %%
#working of python and how it utilize memory

# %%
#primary component of python is VARIABLE 
#vary-->something that keep changing

# %%
#id(x) gives which memory location does variable is pointing out
#memory allocation

# %%
#in python variables acutually does not stores a value.
#a value get's inside of a small part of memory and now that variable points out 
#or refer towards that memory location

# %%
#A value that get's stored inside a memory is called as object
#in python everything is object.
#object has a datatype

# %%
#DATA TYPE -Simply means what kind of data a variable will point towards
#what kind of object a user wants to create .

# %% [markdown]
# ## ndsndkkdvad vdnvmdmsdmc-Markdown

# %% [markdown]
# # 1.PRIMITIVE DATA TYPE
#
# a. Int -integer
# .creates a object form simply means a number
# .a integer object can be negative or positive
# .integer object has range of infinity
# .integer object is immutable data type
# .integer has infinity range

# %%
z=45
print(type(z))

w=-234
print(type(w))
# Out:
# <class 'int'>
# <class 'int'>

# %% [markdown]
# # FLOAT--> It can also be negative , infinite range

# %%
f=-99.6
print(f)
print(type(f))
# Out:
# -99.6
# <class 'float'>

# %% [markdown]
# # COMPLEX-->used for mathematical operations . has real and imaginary part

# %%
c=4+5j
c.real
c.imag
# Out:
# 5.0

# %% [markdown]
# # BOOLEAN--> Returns true or false . It is used for checking condition  , returns true if condition is true , false when condition is false

# %% [markdown]
# # None --> no value . used to show no value or empty value

# %%
Q=25
print(id(Q))
# Out:
# 140720649250472

# %%
f=5
print(id(f))
# Out:
# 140720649249832

# %%
F=5
print(id(F))
# Out:
# 140720649249832

# %%
q=25
print(id(q))
# Out:
# 140720649250472
