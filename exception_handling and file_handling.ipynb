# %%
# Exceptions simply means error inside python code .
# errors stops the entire code from execution . since python executes code line by line .
# so handling those errors is important so that we see smooth execution of code . It has 2 blocks of code 

try : In this block we write the logic which we feel it might throgh error and if it throws any kind of error 
Except : In this block error occured in try block will be resolved with output

# %%
try:
    z=int("fkn")
except:
    print("invalid value")
# Out:
# invalid value

# %%
try:
    a=10
    b=0
    c=a/b
    c
except:
    print("invalid value")
# Out:
# invalid value

# %%
# write a program that takes a user input and converts it into integer

try:
    a=int(input("enter a value"))
    print(a)
    num=[1,2,3,3,4]
    print(num)
except:
    print("invalid value")
# Out:
# enter a value vaishnavi
# invalid value

# %%
# take input from the user and divide by that number
try:
    a=int(input("enter a value"))
    c=500/a
    print(c)
except:
    print("Invalid Value")
# Out:
# enter a value 0
# Invalid Value

# %%
a=int(input("enter a value"))
c=500/a
print(c)
# Out:
# enter a value 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[31], line 2
#       1 a=int(input("enter a value"))
# ----> 2 c=500/a
#       3 print(c)
#
# ZeroDivisionError: division by zero

# %%
# types of error inside python

1.value error = wrong value type given 
2.type error = wrong datatype given 
3.ZeroDivisionError = diving by zero
4.filenotfounderror

# %%
# handling multiple exceptions
try:
    d=int(input("enter a number"))
    y=100/d
    print(y)
except ValueError:
    print("please enter a valid number : ")
except ZeroDivisionError:
    print("cannot divide by zero : ")
# Out:
# enter a number 4+5j
# please enter a valid number :

# %%
d=int(input("enter a number"))
y=100/d
print(y)
# Out:
# enter a number 4
# 25.0

# %%
# %%writefile areaofsquare.py
def square(a):
    return a*a
square(10)
# Out:
# Overwriting areaofsquare.py

# %%
# %%writefile areasquare.py
def square(a):
    return a*a
square(40)
# Out:
# Writing areasquare.py

# %%
a=[1,2,3,4]
b=a.copy()
a is b
# Out:
# False

# %%
b is a
# Out:
# False

# %%
a==b
# Out:
# True

# %%
n1=[1,2,3]
n2=[1,2,3]

# %%
n1==n2
# Out:
# True

# %%
n1 is n2
# Out:
# False

# %%
a=[1,2,3,4,5]
b=a.copy()
b.append(10)
print(b)
# Out:
# [1, 2, 3, 4, 5, 10]

# %%
a is b
# Out:
# False

# %%
c=[1,2,3]
d=c.copy()

# %%
c is d
# Out:
# False

# %%
id(c)
# Out:
# 2129734357504

# %%
id(d)
# Out:
# 2129734589760

# %%
c==d
# Out:
# True

# %%
d==c
# Out:
# True

# %%
x=[10,20,30]
y=[10,20,30]

# %%
x is y
# Out:
# False

# %%
x==y
# Out:
# True

# %%
y==x
# Out:
# True

# %%
y is x
# Out:
# False
